# %%
pip install countryinfo
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from countryinfo import CountryInfo

# %%
name = 'India'

# %%
country = CountryInfo(name)

# %%
country.info()
# Out:
# {'name': 'India',
#  'altSpellings': ['IN', 'Bhārat', 'Republic of India', 'Bharat Ganrajya'],
#  'area': 3287590,
#  'borders': ['AFG', 'BGD', 'BTN', 'MMR', 'CHN', 'NPL', 'PAK', 'LKA'],
#  'callingCodes': ['91'],
#  'capital': 'New Delhi',
#  'capital_latlng': [28.614179, 77.202266],
#  'currencies': ['INR'],
#  'demonym': 'Indian',
#  'flag': '',
#  'geoJSON': {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'id': 'IND',
#     'properties': {'name': 'India'},
#     'geometry': {'type': 'Polygon',
#      'coordinates': [[[77.837451, 35.49401],
#        [78.912269, 34.321936],
#        [78.811086, 33.506198],
#        [79.208892, 32.994395],
#        [79.176129, 32.48378],
#        [78.458446, 32.618164],
#        [78.738894, 31.515906],
#        [79.721367, 30.882715],
#        [81.111256, 30.183481],
#        [80.476721, 29.729865],
#        [80.088425, 28.79447],
#        [81.057203, 28.416095],
#        [81.999987, 27.925479],
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_33016/4114412568.py in <module>
# ----> 1 country.describe()
#
# AttributeError: 'CountryInfo' object has no attribute 'describe'
